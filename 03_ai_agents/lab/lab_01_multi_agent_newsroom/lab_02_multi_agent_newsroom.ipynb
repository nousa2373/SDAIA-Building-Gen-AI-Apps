# %% [markdown]
# # Lab 2: The Plan-and-Execute Newsroom
#
# Build a multi-agent system that uses a Planner to decompose tasks and specialist agents (researcher, analyst, writer) to execute them. Uses `@observe` from Lab 1 for end-to-end observability.

# %% [markdown]
# ## Phase 0: Setup and Imports

# %%
import requests
import json
import os
import asyncio
import logging
from typing import List
from bs4 import BeautifulSoup
from litellm import acompletion
from pydantic import BaseModel, Field
from deepeval.tracing import observe
import nest_asyncio

nest_asyncio.apply()
from dotenv import load_dotenv
load_dotenv()

MODEL_NAME = "openrouter/nvidia/nemotron-3-super-120b-a12b:free"
print(f'Environment loaded. Model: {MODEL_NAME}')
# Out:
# Environment loaded. Model: openrouter/nvidia/nemotron-3-super-120b-a12b:free

# %% [markdown]
# ### Tool Belt
# Pre-built tools for live web search.

# %%
def search_web(query, max_results=3):
    url = 'https://html.duckduckgo.com/html/'
    headers = {'User-Agent': 'Mozilla/5.0'}
    try:
        resp = requests.post(url, data={'q': query}, headers=headers, timeout=10)
        resp.raise_for_status()
        soup = BeautifulSoup(resp.text, 'html.parser')
        results = []
        for res in soup.find_all('div', class_='result', limit=max_results):
            title_tag = res.find('a', class_='result__a')
            snippet_tag = res.find('a', class_='result__snippet')
            if title_tag and snippet_tag:
                results.append({'title': title_tag.get_text(strip=True), 'link': title_tag['href'], 'snippet': snippet_tag.get_text(strip=True)})
        return json.dumps(results)
    except Exception as e:
        return f'Search error: {e}'

print('Tool Belt loaded.')
# Out:
# Tool Belt loaded.

# %% [markdown]
# ## Phase 1: Specialist Prompts
#
# Define the system prompts for each specialist. The **Researcher** has access to `search_web`.

# %%
SPECIALIST_PROMPTS = {
    'researcher': 'You are a Research Specialist. Use the search_web tool to find real-time information and cite your sources.',
    'analyst': 'You are an Analysis Specialist. Evaluate the research, flag contradictions, and rate your confidence.',
    'writer': 'You are a Writing Specialist. Synthesize the analysis into a polished report with clear headings.',
}

SEARCH_TOOL_SCHEMA = [{
    'type': 'function',
    'function': {
        'name': 'search_web',
        'description': 'Search the web for real-time information.',
        'parameters': {'type': 'object', 'properties': {'query': {'type': 'string'}}, 'required': ['query']}
    }
}]

@observe(type='tool')
async def call_specialist(specialist, task):
    prompt = SPECIALIST_PROMPTS.get(specialist, 'You are a helpful assistant.')
    messages = [
        {'role': 'system', 'content': prompt},
        {'role': 'user', 'content': task}
    ]
    tools = SEARCH_TOOL_SCHEMA if specialist == 'researcher' else None
    resp = await acompletion(model=MODEL_NAME, messages=messages, tools=tools)
    msg = resp.choices[0].message
    if specialist == 'researcher' and hasattr(msg, 'tool_calls') and msg.tool_calls:
        for tc in msg.tool_calls:
            if tc.function.name == 'search_web':
                args = json.loads(tc.function.arguments)
                result = search_web(args['query'])
                messages.append(msg.model_dump())
                messages.append({'role': 'tool', 'tool_call_id': tc.id, 'content': result})
                final = await acompletion(model=MODEL_NAME, messages=messages)
                return final.choices[0].message.content
    return msg.content

print('Specialist system ready.')
# Out:
# Specialist system ready.

# %% [markdown]
# ## Phase 2: The Planner
#
# The Planner decomposes a query into ordered specialist steps using structured output.

# %%
class PlanStep(BaseModel):
    step: int = Field(..., description='Step number')
    task: str = Field(..., description='Task to perform')
    specialist: str = Field(..., description='One of: researcher, analyst, writer')
    depends_on: List[int] = Field(default_factory=list)

class Plan(BaseModel):
    steps: List[PlanStep]

PLANNER_PROMPT = '''You are a task planner for a newsroom.
Specialists: researcher (finds facts), analyst (evaluates), writer (synthesizes report).
Decompose the query into minimal ordered steps. researcher steps can run independently.
Query: {query}'''

class TaskPlanner:
    @observe(type='agent')
    async def create_plan(self, query):
        resp = await acompletion(
            model=MODEL_NAME,
            messages=[{'role': 'user', 'content': PLANNER_PROMPT.format(query=query)}],
            response_format=Plan
        )
        plan = Plan.model_validate_json(resp.choices[0].message.content)
        return [s.model_dump() for s in plan.steps]

print('TaskPlanner ready.')
# Out:
# TaskPlanner ready.

# %% [markdown]
# ## Phase 3: The Newsroom Agent
#
# Orchestrates planning and execution. Results from one step feed into the next as context.

# %%
class NewsroomAgent:
    def __init__(self):
        self.planner = TaskPlanner()
        self.logger = logging.getLogger('Newsroom')
        logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s %(message)s', datefmt='%H:%M:%S')

    def _get_context(self, step, results):
        parts = [f'[Step {d} result]:\n{results[d]}' for d in step.get('depends_on', []) if d in results]
        return '\n\n'.join(parts)

    @observe(type='agent')
    async def run(self, query):
        self.logger.info('Planning...')
        plan = await self.planner.create_plan(query)
        for s in plan:
            self.logger.info(f'  Step {s["step"]} [{s["specialist"]}]: {s["task"]}')

        self.logger.info('Executing...')
        results = {}
        for step in plan:
            context = self._get_context(step, results)
            full_task = step['task'] if not context else f'{step["task"]}\n\nContext:\n{context}'
            self.logger.info(f'Running Step {step["step"]} [{step["specialist"]}]...')
            results[step['step']] = await call_specialist(step['specialist'], full_task)

        self.logger.info('Synthesizing...')
        summary = '\n'.join([f'Step {k}: {v}' for k, v in sorted(results.items())])
        final_resp = await acompletion(
            model=MODEL_NAME,
            messages=[
                {'role': 'system', 'content': 'Write a final cited report from these research findings.'},
                {'role': 'user', 'content': f'Query: {query}\n\nFindings:\n{summary}'}
            ]
        )
        return final_resp.choices[0].message.content

print('NewsroomAgent ready.')
# Out:
# NewsroomAgent ready.

# %% [markdown]
# ## Phase 4: Run the Agent
#
# Change `query` to any research topic and run!

# %%
async def main():
    agent = NewsroomAgent()
    query = 'Compare AI regulations in the EU and Saudi Arabia'
    report = await agent.run(query)
    print(f'\n--- FINAL REPORT ---\n{report}')

#await main()
import asyncio
asyncio.run(main())
# Out:
# 11:10:12 INFO Planning...
# 11:10:12 - LiteLLM:INFO: utils.py:4007 -
# LiteLLM completion() model= nvidia/nemotron-3-super-120b-a12b:free; provider = openrouter
# 11:10:12 INFO
# LiteLLM completion() model= nvidia/nemotron-3-super-120b-a12b:free; provider = openrouter
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# [Confident AI Trace Log]  No Confident AI API key found. Skipping trace posting.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:203, in BaseLLMHTTPHandler._make_common_async_call(self, async_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     201                     raise self._handle_error(e=e, provider_config=provider_config)
#     202             except Exception as e:
# --> 203                 raise self._handle_error(e=e, provider_config=provider_config)
#     204             break
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\litellm_core_utils\logging_utils.py:297, in track_llm_api_timing.<locals>.decorator.<locals>.async_wrapper(*args, **kwargs)
#     296 try:
# --> 297     result = await func(*args, **kwargs)
#     298     return result
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:515, in AsyncHTTPHandler.post(self, url, data, json, params, headers, timeout, stream, logging_obj, files, content)
#     514 except Exception as e:
# --> 515     raise e
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\llms\custom_httpx\http_handler.py:468, in AsyncHTTPHandler.post(self, url, data, json, params, headers, timeout, stream, logging_obj, files, content)
#     457 req = self.client.build_request(
#     458     "POST",
#     459     url,
#    (...)    466     content=request_content,
#     467 )
# --> 468 response = await self.client.send(req, stream=stream)
#     469 response.raise_for_status()
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\httpx\_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\httpx\_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\httpx\_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\httpx\_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\llms\custom_httpx\aiohttp_transport.py:307, in LiteLLMAiohttpTransport.handle_async_request(self, request)
#     306     with map_aiohttp_exceptions():
# --> 307         response = await self._make_aiohttp_request(
#     308             client_session=client_session,
#     309             request=request,
#     310             timeout=timeout,
#     311             proxy=proxy,
#     312             sni_hostname=sni_hostname,
#     313             ssl_verify=ssl_config,
#     314         )
#     315 except RuntimeError as e:
#     316     # Handle the case where session was closed between our check and actual use
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\llms\custom_httpx\aiohttp_transport.py:285, in LiteLLMAiohttpTransport._make_aiohttp_request(self, client_session, request, timeout, proxy, sni_hostname, ssl_verify)
#     283     request_kwargs["ssl"] = ssl_verify
# --> 285 response = await client_session.request(**request_kwargs).__aenter__()
#     287 return response
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\aiohttp\client.py:1521, in _BaseRequestContextManager.__aenter__(self)
#    1520 async def __aenter__(self) -> _RetType:
# -> 1521     self._resp: _RetType = await self._coro
#    1522     return await self._resp.__aenter__()
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\aiohttp\client.py:788, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size, max_headers, middlewares)
#     787 try:
# --> 788     resp = await handler(req)
#     789 # Client connector errors should not be retried
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\aiohttp\client.py:742, in ClientSession._request.<locals>._connect_and_send_request(req)
#     741 try:
# --> 742     conn = await self._connector.connect(
#     743         req, traces=traces, timeout=real_timeout
#     744     )
#     745 except asyncio.TimeoutError as exc:
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\aiohttp\connector.py:650, in BaseConnector.connect(self, req, traces, timeout)
#     648     return conn
# --> 650 async with ceil_timeout(timeout.connect, timeout.ceil_threshold):
#     651     if self._available_connections(key) <= 0:
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\asyncio\timeouts.py:88, in Timeout.__aenter__(self)
#      87 if task is None:
# ---> 88     raise RuntimeError("Timeout should be used inside a task")
#      89 self._state = _State.ENTERED
#
# RuntimeError: Timeout should be used inside a task
#
# During handling of the above exception, another exception occurred:
#
# OpenRouterException                       Traceback (most recent call last)
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\main.py:620, in acompletion(model, messages, functions, function_call, timeout, temperature, top_p, n, stream, stream_options, stop, max_tokens, max_completion_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, parallel_tool_calls, logprobs, top_logprobs, deployment_id, reasoning_effort, verbosity, safety_identifier, service_tier, base_url, api_version, api_key, model_list, extra_headers, thinking, web_search_options, shared_session, enable_json_schema_validation, **kwargs)
#     619 elif asyncio.iscoroutine(init_response):
# --> 620     response = await init_response
#     621 else:
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:308, in BaseLLMHTTPHandler.async_completion(self, custom_llm_provider, provider_config, api_base, headers, data, timeout, model, model_response, logging_obj, messages, optional_params, litellm_params, encoding, api_key, client, json_mode, signed_json_body, shared_session)
#     306             async_httpx_client = client
#     307
# --> 308         response = await self._make_common_async_call(
#     309             async_httpx_client=async_httpx_client,
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:203, in BaseLLMHTTPHandler._make_common_async_call(self, async_httpx_client, provider_config, api_base, headers, data, timeout, litellm_params, logging_obj, stream, signed_json_body)
#     201                     raise self._handle_error(e=e, provider_config=provider_config)
#     202             except Exception as e:
# --> 203                 raise self._handle_error(e=e, provider_config=provider_config)
#     204             break
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\llms\custom_httpx\llm_http_handler.py:4721, in BaseLLMHTTPHandler._handle_error(self, e, provider_config)
#    4719             )
#    4720
# -> 4721         raise provider_config.get_error_class(
#    4722             error_message=error_text,
#
# OpenRouterException: Timeout should be used inside a task
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# Cell In[53], line 9
#       5     print(f'\n--- FINAL REPORT ---\n{report}')
#       6
#       7 #await main()
#       8 import asyncio
# ----> 9 asyncio.run(main())
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\asyncio\futures.py:208, in Future.result(self)
#     206 self.__log_traceback = False
#     207 if self._exception is not None:
# --> 208     raise self._exception.with_traceback(self._exception_tb)
#     209 return self._result
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\asyncio\tasks.py:289, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     285 try:
#     286     if exc is None:
#     287         # We use the `send` method directly, because coroutines
#     288         # don't have `__iter__` and `__next__` methods.
# --> 289         result = coro.send(None)
#     290     else:
#     291         result = coro.throw(exc)
#
# Cell In[53], line 4, in main()
#       1 async def main():
#       2     agent = NewsroomAgent()
#       3     query = 'Compare AI regulations in the EU and Saudi Arabia'
# ----> 4     report = await agent.run(query)
#       5     print(f'\n--- FINAL REPORT ---\n{report}')
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\deepeval\tracing\tracing.py:942, in observe.<locals>.decorator.<locals>.async_wrapper(*args, **func_kwargs)
#     930 observer_kwargs = {
#     931     "observe_kwargs": observe_kwargs,
#     932     "function_kwargs": complete_kwargs,  # Now contains all args mapped to their names
#     933 }
#     934 with Observer(
#     935     type,
#     936     metrics=metrics,
#    (...)    940 ) as observer:
#     941     # Call the original function
# --> 942     result = await func(*args, **func_kwargs)
#     943     # Capture the result
#     944     observer.result = result
#
# Cell In[38], line 14, in NewsroomAgent.run(self, query)
#      11     @observe(type='agent')
#      12     async def run(self, query):
#      13         self.logger.info('Planning...')
# ---> 14         plan = await self.planner.create_plan(query)
#      15         for s in plan:
#      16             self.logger.info(f'  Step {s["step"]} [{s["specialist"]}]: {s["task"]}')
#      17
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\deepeval\tracing\tracing.py:942, in observe.<locals>.decorator.<locals>.async_wrapper(*args, **func_kwargs)
#     930 observer_kwargs = {
#     931     "observe_kwargs": observe_kwargs,
#     932     "function_kwargs": complete_kwargs,  # Now contains all args mapped to their names
#     933 }
#     934 with Observer(
#     935     type,
#     936     metrics=metrics,
#    (...)    940 ) as observer:
#     941     # Call the original function
# --> 942     result = await func(*args, **func_kwargs)
#     943     # Capture the result
#     944     observer.result = result
#
# Cell In[36], line 18, in TaskPlanner.create_plan(self, query)
#      16     @observe(type='agent')
#      17     async def create_plan(self, query):
# ---> 18         resp = await acompletion(
#      19             model=MODEL_NAME,
#      20             messages=[{'role': 'user', 'content': PLANNER_PROMPT.format(query=query)}],
#      21             response_format=Plan
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\utils.py:2093, in client.<locals>.wrapper_async(*args, **kwargs)
#    2091 timeout = _get_wrapper_timeout(kwargs=kwargs, exception=e)
#    2092 setattr(e, "timeout", timeout)
# -> 2093 raise e
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\utils.py:1892, in client.<locals>.wrapper_async(*args, **kwargs)
#    1889         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1891 # MODEL CALL
# -> 1892 result = await original_function(*args, **kwargs)
#    1893 end_time = datetime.datetime.now()
#    1895 if _is_streaming_request(
#    1896     kwargs=kwargs,
#    1897     call_type=call_type,
#    1898 ):
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\main.py:639, in acompletion(model, messages, functions, function_call, timeout, temperature, top_p, n, stream, stream_options, stop, max_tokens, max_completion_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, response_format, seed, tools, tool_choice, parallel_tool_calls, logprobs, top_logprobs, deployment_id, reasoning_effort, verbosity, safety_identifier, service_tier, base_url, api_version, api_key, model_list, extra_headers, thinking, web_search_options, shared_session, enable_json_schema_validation, **kwargs)
#     637 except Exception as e:
#     638     custom_llm_provider = custom_llm_provider or "openai"
# --> 639     raise exception_type(
#     640         model=model,
#     641         custom_llm_provider=custom_llm_provider,
#     642         original_exception=e,
#     643         completion_kwargs=completion_kwargs,
#     644         extra_kwargs=kwargs,
#     645     )
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2456, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2454 if exception_mapping_worked:
#    2455     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2456     raise e
#    2457 else:
#    2458     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File c:\Users\nora_\Desktop\SDAIA-Building-Gen-AI-Apps\.venv\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2389, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2387     else:
#    2388         exception_mapping_worked = True
# -> 2389         raise APIError(
#    2390             status_code=original_exception.status_code,
#    2391             message=f"APIError: {exception_provider} - {error_str}",
#    2392             llm_provider=custom_llm_provider,
#    2393             model=model,
#    2394             request=getattr(original_exception, "request", None),
#    2395             litellm_debug_info=extra_information,
#    2396         )
#    2397 else:
#    2398     # if no status code then it is an APIConnectionError: https://github.com/openai/openai-python#handling-errors
#    2399     raise APIConnectionError(
#    2400         message=f"APIConnectionError: {exception_provider} - {error_str}",
#    2401         llm_provider=custom_llm_provider,
#    (...)   2406         ),
#    2407     )
#
# APIError: litellm.APIError: APIError: OpenrouterException - Timeout should be used inside a task
